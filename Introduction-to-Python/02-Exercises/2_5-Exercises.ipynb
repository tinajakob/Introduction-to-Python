# %% [markdown]
# *Part 2: Python for Data Analysis V*
# ### Plotting II
# #Exercises#

# %% [markdown]
# For this exercise, we will use the following dataset:
# * ``http://farys.org/daten/allbus.dta`` (Excerpt from the German General Social Survey 2008)
#
# You can read the file using pandas `read_stata()`:

# %%
import pandas as pd
df = pd.read_stata("http://farys.org/daten/allbus.dta")

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# Use `seaborn` to create a histogram of the variable `bmi` (Body-Mass-Index) to get an impression of the distribution.

# %% [markdown]
# That does not look right! Fix the values that should actually be NaN and plot the histogram again.

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# You want to create a ranking - highest to lowest Body-Mass-Index by median - for all states (Bundesländer) in Germany. The information is stored in `state`. Create a boxplot using seaborn.

# %% [markdown]
# ## Exercise 3

# %% [markdown]
# Now create a scatterplot with regression line (`lmplot`) for the relationship between `bmi` (Y) and `income` (X). Be sure to clean the income column first as there are wrong values (99997-99999) which should be NaN.

# %% [markdown]
# If you look at the scatterplot, you notice some outliers. Create an interactive plot using `altair` so you can inspect these outliers, i.e. when you hover over potential outliers you want to see the values of their occupation in a tooltip. If you like, you can add more information to the tooltip like age, sex, state,...

# %% [markdown]
# ## Exercise 4

# %% [markdown]
# Use `geopandas` and read the world shapefile from the tutorial.

# %% [markdown]
# Merge the data with the life-satisfaction data. You might need to add the code snippet from the tutorial to add the 3-character codes to the geopandas dataFrame.

# %% [markdown]
# Plot a map and color the countries by the value of life satisfaction. If you like you can also play a bit with different color palettes.

# %% [markdown]
# Now try to find a nice base map and plot the life satisfaction data on top of it.
